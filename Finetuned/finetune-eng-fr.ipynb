# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import pandas as pd
import numpy as np

print(torch.cuda.is_available())
# Out:
# True

# %%
data = pd.read_csv('eng_-french.csv')
data.head()
# Out:
#   English words/sentences French words/sentences
# 0                     Hi.                 Salut!
# 1                    Run!                Cours !
# 2                    Run!               Courez !
# 3                    Who?                  Qui ?
# 4                    Wow!             Ça alors !

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

model_name = "Helsinki-NLP/opus-mt-en-fr"
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# c:\Users\UYW1KOR\AppData\Local\anaconda3\envs\projects\Lib\site-packages\transformers\models\marian\tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")

# %%
eng = data['English words/sentences'][:5000]
fr = data['French words/sentences'][:5000]

# %%
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split

eng_train, eng_test, fr_train, fr_test = train_test_split(eng, fr, test_size=0.2, random_state=42)


def tokenize(sentences, max_length=50):
    return tokenizer(sentences, padding='max_length', truncation=True, max_length=max_length, return_tensors="pt")

def preprocessed_fn(data):
    src = data['en']
    tgt = data['fr']
    src_enc = tokenize(src)
    tgt_enc = tokenize(tgt) 
    model_inputs = {
        "input_ids" : src_enc["input_ids"],
        "attention_mask" : src_enc["attention_mask"],
        "labels" : tgt_enc["input_ids"]
    }
    return model_inputs

# %%
batch_size = 16

from datasets import Dataset
train_dataset = Dataset.from_dict({"en": eng_train, "fr": fr_train})
test_dataset = Dataset.from_dict({"en": eng_test, "fr": fr_test})

tokenized_train = train_dataset.map(preprocessed_fn, batched=True, remove_columns=['en', 'fr'])
tokenized_test = test_dataset.map(preprocessed_fn, batched=True, remove_columns=['en', 'fr'])
# Out:
# Map:   0%|          | 0/4000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]

# %%
tokenized_train
# Out:
# Dataset({
#     features: ['inpu_ids', 'attention_mask', 'labels'],
#     num_rows: 4000
# })

# %%
for name, module in model.named_modules():
    print(name)
# Out:
# base_model
# base_model.model
# base_model.model.model
# base_model.model.model.shared
# base_model.model.model.encoder
# base_model.model.model.encoder.embed_positions
# base_model.model.model.encoder.layers
# base_model.model.model.encoder.layers.0
# base_model.model.model.encoder.layers.0.self_attn
# base_model.model.model.encoder.layers.0.self_attn.k_proj
# base_model.model.model.encoder.layers.0.self_attn.k_proj.base_layer
# base_model.model.model.encoder.layers.0.self_attn.k_proj.lora_dropout
# base_model.model.model.encoder.layers.0.self_attn.k_proj.lora_dropout.default
# base_model.model.model.encoder.layers.0.self_attn.k_proj.lora_A
# base_model.model.model.encoder.layers.0.self_attn.k_proj.lora_A.default
# base_model.model.model.encoder.layers.0.self_attn.k_proj.lora_B
# base_model.model.model.encoder.layers.0.self_attn.k_proj.lora_B.default
# base_model.model.model.encoder.layers.0.self_attn.k_proj.lora_embedding_A
# base_model.model.model.encoder.layers.0.self_attn.k_proj.lora_embedding_B
# base_model.model.model.encoder.layers.0.self_attn.k_proj.lora_magnitude_vector
# base_model.model.model.encoder.layers.0.self_attn.v_proj
# base_model.model.model.encoder.layers.0.self_attn.v_proj.base_layer
# base_model.model.model.encoder.layers.0.self_attn.v_proj.lora_dropout
# base_model.model.model.encoder.layers.0.self_attn.v_proj.lora_dropout.default
# base_model.model.model.encoder.layers.0.self_attn.v_proj.lora_A
# base_model.model.model.encoder.layers.0.self_attn.v_proj.lora_A.default
# base_model.model.model.encoder.layers.0.self_attn.v_proj.lora_B
# base_model.model.model.encoder.layers.0.self_attn.v_proj.lora_B.default
# base_model.model.model.encoder.layers.0.self_attn.v_proj.lora_embedding_A
# base_model.model.model.encoder.layers.0.self_attn.v_proj.lora_embedding_B
# base_model.model.model.encoder.layers.0.self_attn.v_proj.lora_magnitude_vector
# base_model.model.model.encoder.layers.0.self_attn.q_proj
# base_model.model.model.encoder.layers.0.self_attn.q_proj.base_layer
# base_model.model.model.encoder.layers.0.self_attn.q_proj.lora_dropout
# base_model.model.model.encoder.layers.0.self_attn.q_proj.lora_dropout.default
# base_model.model.model.encoder.layers.0.self_attn.q_proj.lora_A
# base_model.model.model.encoder.layers.0.self_attn.q_proj.lora_A.default
# base_model.model.model.encoder.layers.0.self_attn.q_proj.lora_B
# base_model.model.model.encoder.layers.0.self_attn.q_proj.lora_B.default
# base_model.model.model.encoder.layers.0.self_attn.q_proj.lora_embedding_A
# base_model.model.model.encoder.layers.0.self_attn.q_proj.lora_embedding_B
# base_model.model.model.encoder.layers.0.self_attn.q_proj.lora_magnitude_vector
# base_model.model.model.encoder.layers.0.self_attn.out_proj
# base_model.model.model.encoder.layers.0.self_attn_layer_norm
# base_model.model.model.encoder.layers.0.activation_fn
# base_model.model.model.encoder.layers.0.fc1
# base_model.model.model.encoder.layers.0.fc2
# base_model.model.model.encoder.layers.0.final_layer_norm
# base_model.model.model.encoder.layers.1
# base_model.model.model.encoder.layers.1.self_attn
# base_model.model.model.encoder.layers.1.self_attn.k_proj
# base_model.model.model.encoder.layers.1.self_attn.k_proj.base_layer
# base_model.model.model.encoder.layers.1.self_attn.k_proj.lora_dropout
# base_model.model.model.encoder.layers.1.self_attn.k_proj.lora_dropout.default
# base_model.model.model.encoder.layers.1.self_attn.k_proj.lora_A
# base_model.model.model.encoder.layers.1.self_attn.k_proj.lora_A.default
# base_model.model.model.encoder.layers.1.self_attn.k_proj.lora_B
# base_model.model.model.encoder.layers.1.self_attn.k_proj.lora_B.default
# base_model.model.model.encoder.layers.1.self_attn.k_proj.lora_embedding_A
# base_model.model.model.encoder.layers.1.self_attn.k_proj.lora_embedding_B
# base_model.model.model.encoder.layers.1.self_attn.k_proj.lora_magnitude_vector
# base_model.model.model.encoder.layers.1.self_attn.v_proj
# base_model.model.model.encoder.layers.1.self_attn.v_proj.base_layer
# base_model.model.model.encoder.layers.1.self_attn.v_proj.lora_dropout
# base_model.model.model.encoder.layers.1.self_attn.v_proj.lora_dropout.default
# base_model.model.model.encoder.layers.1.self_attn.v_proj.lora_A
# base_model.model.model.encoder.layers.1.self_attn.v_proj.lora_A.default
# base_model.model.model.encoder.layers.1.self_attn.v_proj.lora_B
# base_model.model.model.encoder.layers.1.self_attn.v_proj.lora_B.default
# base_model.model.model.encoder.layers.1.self_attn.v_proj.lora_embedding_A
# base_model.model.model.encoder.layers.1.self_attn.v_proj.lora_embedding_B
# base_model.model.model.encoder.layers.1.self_attn.v_proj.lora_magnitude_vector
# base_model.model.model.encoder.layers.1.self_attn.q_proj
# base_model.model.model.encoder.layers.1.self_attn.q_proj.base_layer
# base_model.model.model.encoder.layers.1.self_attn.q_proj.lora_dropout
# base_model.model.model.encoder.layers.1.self_attn.q_proj.lora_dropout.default
# base_model.model.model.encoder.layers.1.self_attn.q_proj.lora_A
# base_model.model.model.encoder.layers.1.self_attn.q_proj.lora_A.default
# base_model.model.model.encoder.layers.1.self_attn.q_proj.lora_B
# base_model.model.model.encoder.layers.1.self_attn.q_proj.lora_B.default
# base_model.model.model.encoder.layers.1.self_attn.q_proj.lora_embedding_A
# base_model.model.model.encoder.layers.1.self_attn.q_proj.lora_embedding_B
# base_model.model.model.encoder.layers.1.self_attn.q_proj.lora_magnitude_vector
# base_model.model.model.encoder.layers.1.self_attn.out_proj
# base_model.model.model.encoder.layers.1.self_attn_layer_norm
# base_model.model.model.encoder.layers.1.activation_fn
# base_model.model.model.encoder.layers.1.fc1
# base_model.model.model.encoder.layers.1.fc2
# base_model.model.model.encoder.layers.1.final_layer_norm
# base_model.model.model.encoder.layers.2
# base_model.model.model.encoder.layers.2.self_attn
# base_model.model.model.encoder.layers.2.self_attn.k_proj
# base_model.model.model.encoder.layers.2.self_attn.k_proj.base_layer
# base_model.model.model.encoder.layers.2.self_attn.k_proj.lora_dropout
# base_model.model.model.encoder.layers.2.self_attn.k_proj.lora_dropout.default
# base_model.model.model.encoder.layers.2.self_attn.k_proj.lora_A
# base_model.model.model.encoder.layers.2.self_attn.k_proj.lora_A.default
# base_model.model.model.encoder.layers.2.self_attn.k_proj.lora_B
# base_model.model.model.encoder.layers.2.self_attn.k_proj.lora_B.default
# base_model.model.model.encoder.layers.2.self_attn.k_proj.lora_embedding_A
# base_model.model.model.encoder.layers.2.self_attn.k_proj.lora_embedding_B
# base_model.model.model.encoder.layers.2.self_attn.k_proj.lora_magnitude_vector
# base_model.model.model.encoder.layers.2.self_attn.v_proj
# base_model.model.model.encoder.layers.2.self_attn.v_proj.base_layer
# base_model.model.model.encoder.layers.2.self_attn.v_proj.lora_dropout
# base_model.model.model.encoder.layers.2.self_attn.v_proj.lora_dropout.default
# base_model.model.model.encoder.layers.2.self_attn.v_proj.lora_A
# base_model.model.model.encoder.layers.2.self_attn.v_proj.lora_A.default
# base_model.model.model.encoder.layers.2.self_attn.v_proj.lora_B
# base_model.model.model.encoder.layers.2.self_attn.v_proj.lora_B.default
# base_model.model.model.encoder.layers.2.self_attn.v_proj.lora_embedding_A
# base_model.model.model.encoder.layers.2.self_attn.v_proj.lora_embedding_B
# base_model.model.model.encoder.layers.2.self_attn.v_proj.lora_magnitude_vector
# base_model.model.model.encoder.layers.2.self_attn.q_proj
# base_model.model.model.encoder.layers.2.self_attn.q_proj.base_layer
# base_model.model.model.encoder.layers.2.self_attn.q_proj.lora_dropout
# base_model.model.model.encoder.layers.2.self_attn.q_proj.lora_dropout.default
# base_model.model.model.encoder.layers.2.self_attn.q_proj.lora_A
# base_model.model.model.encoder.layers.2.self_attn.q_proj.lora_A.default
# base_model.model.model.encoder.layers.2.self_attn.q_proj.lora_B
# base_model.model.model.encoder.layers.2.self_attn.q_proj.lora_B.default
# base_model.model.model.encoder.layers.2.self_attn.q_proj.lora_embedding_A
# base_model.model.model.encoder.layers.2.self_attn.q_proj.lora_embedding_B
# base_model.model.model.encoder.layers.2.self_attn.q_proj.lora_magnitude_vector
# base_model.model.model.encoder.layers.2.self_attn.out_proj
# base_model.model.model.encoder.layers.2.self_attn_layer_norm
# base_model.model.model.encoder.layers.2.activation_fn
# base_model.model.model.encoder.layers.2.fc1
# base_model.model.model.encoder.layers.2.fc2
# base_model.model.model.encoder.layers.2.final_layer_norm
# base_model.model.model.encoder.layers.3
# base_model.model.model.encoder.layers.3.self_attn
# base_model.model.model.encoder.layers.3.self_attn.k_proj
# base_model.model.model.encoder.layers.3.self_attn.k_proj.base_layer
# base_model.model.model.encoder.layers.3.self_attn.k_proj.lora_dropout
# base_model.model.model.encoder.layers.3.self_attn.k_proj.lora_dropout.default
# base_model.model.model.encoder.layers.3.self_attn.k_proj.lora_A
# base_model.model.model.encoder.layers.3.self_attn.k_proj.lora_A.default
# base_model.model.model.encoder.layers.3.self_attn.k_proj.lora_B
# base_model.model.model.encoder.layers.3.self_attn.k_proj.lora_B.default
# base_model.model.model.encoder.layers.3.self_attn.k_proj.lora_embedding_A
# base_model.model.model.encoder.layers.3.self_attn.k_proj.lora_embedding_B
# base_model.model.model.encoder.layers.3.self_attn.k_proj.lora_magnitude_vector
# base_model.model.model.encoder.layers.3.self_attn.v_proj
# base_model.model.model.encoder.layers.3.self_attn.v_proj.base_layer
# base_model.model.model.encoder.layers.3.self_attn.v_proj.lora_dropout
# base_model.model.model.encoder.layers.3.self_attn.v_proj.lora_dropout.default
# base_model.model.model.encoder.layers.3.self_attn.v_proj.lora_A
# base_model.model.model.encoder.layers.3.self_attn.v_proj.lora_A.default
# base_model.model.model.encoder.layers.3.self_attn.v_proj.lora_B
# base_model.model.model.encoder.layers.3.self_attn.v_proj.lora_B.default
# base_model.model.model.encoder.layers.3.self_attn.v_proj.lora_embedding_A
# base_model.model.model.encoder.layers.3.self_attn.v_proj.lora_embedding_B
# base_model.model.model.encoder.layers.3.self_attn.v_proj.lora_magnitude_vector
# base_model.model.model.encoder.layers.3.self_attn.q_proj
# base_model.model.model.encoder.layers.3.self_attn.q_proj.base_layer
# base_model.model.model.encoder.layers.3.self_attn.q_proj.lora_dropout
# base_model.model.model.encoder.layers.3.self_attn.q_proj.lora_dropout.default
# base_model.model.model.encoder.layers.3.self_attn.q_proj.lora_A
# base_model.model.model.encoder.layers.3.self_attn.q_proj.lora_A.default
# base_model.model.model.encoder.layers.3.self_attn.q_proj.lora_B
# base_model.model.model.encoder.layers.3.self_attn.q_proj.lora_B.default
# base_model.model.model.encoder.layers.3.self_attn.q_proj.lora_embedding_A
# base_model.model.model.encoder.layers.3.self_attn.q_proj.lora_embedding_B
# base_model.model.model.encoder.layers.3.self_attn.q_proj.lora_magnitude_vector
# base_model.model.model.encoder.layers.3.self_attn.out_proj
# base_model.model.model.encoder.layers.3.self_attn_layer_norm
# base_model.model.model.encoder.layers.3.activation_fn
# base_model.model.model.encoder.layers.3.fc1
# base_model.model.model.encoder.layers.3.fc2
# base_model.model.model.encoder.layers.3.final_layer_norm
# base_model.model.model.encoder.layers.4
# base_model.model.model.encoder.layers.4.self_attn
# base_model.model.model.encoder.layers.4.self_attn.k_proj
# base_model.model.model.encoder.layers.4.self_attn.k_proj.base_layer
# base_model.model.model.encoder.layers.4.self_attn.k_proj.lora_dropout
# base_model.model.model.encoder.layers.4.self_attn.k_proj.lora_dropout.default
# base_model.model.model.encoder.layers.4.self_attn.k_proj.lora_A
# base_model.model.model.encoder.layers.4.self_attn.k_proj.lora_A.default
# base_model.model.model.encoder.layers.4.self_attn.k_proj.lora_B
# base_model.model.model.encoder.layers.4.self_attn.k_proj.lora_B.default
# base_model.model.model.encoder.layers.4.self_attn.k_proj.lora_embedding_A
# base_model.model.model.encoder.layers.4.self_attn.k_proj.lora_embedding_B
# base_model.model.model.encoder.layers.4.self_attn.k_proj.lora_magnitude_vector
# base_model.model.model.encoder.layers.4.self_attn.v_proj
# base_model.model.model.encoder.layers.4.self_attn.v_proj.base_layer
# base_model.model.model.encoder.layers.4.self_attn.v_proj.lora_dropout
# base_model.model.model.encoder.layers.4.self_attn.v_proj.lora_dropout.default
# base_model.model.model.encoder.layers.4.self_attn.v_proj.lora_A
# base_model.model.model.encoder.layers.4.self_attn.v_proj.lora_A.default
# base_model.model.model.encoder.layers.4.self_attn.v_proj.lora_B
# base_model.model.model.encoder.layers.4.self_attn.v_proj.lora_B.default
# base_model.model.model.encoder.layers.4.self_attn.v_proj.lora_embedding_A
# base_model.model.model.encoder.layers.4.self_attn.v_proj.lora_embedding_B
# base_model.model.model.encoder.layers.4.self_attn.v_proj.lora_magnitude_vector
# base_model.model.model.encoder.layers.4.self_attn.q_proj
# base_model.model.model.encoder.layers.4.self_attn.q_proj.base_layer
# base_model.model.model.encoder.layers.4.self_attn.q_proj.lora_dropout
# base_model.model.model.encoder.layers.4.self_attn.q_proj.lora_dropout.default
# base_model.model.model.encoder.layers.4.self_attn.q_proj.lora_A
# base_model.model.model.encoder.layers.4.self_attn.q_proj.lora_A.default
# base_model.model.model.encoder.layers.4.self_attn.q_proj.lora_B
# base_model.model.model.encoder.layers.4.self_attn.q_proj.lora_B.default
# base_model.model.model.encoder.layers.4.self_attn.q_proj.lora_embedding_A
# base_model.model.model.encoder.layers.4.self_attn.q_proj.lora_embedding_B
# base_model.model.model.encoder.layers.4.self_attn.q_proj.lora_magnitude_vector
# base_model.model.model.encoder.layers.4.self_attn.out_proj
# base_model.model.model.encoder.layers.4.self_attn_layer_norm
# base_model.model.model.encoder.layers.4.activation_fn
# base_model.model.model.encoder.layers.4.fc1
# base_model.model.model.encoder.layers.4.fc2
# base_model.model.model.encoder.layers.4.final_layer_norm
# base_model.model.model.encoder.layers.5
# base_model.model.model.encoder.layers.5.self_attn
# base_model.model.model.encoder.layers.5.self_attn.k_proj
# base_model.model.model.encoder.layers.5.self_attn.k_proj.base_layer
# base_model.model.model.encoder.layers.5.self_attn.k_proj.lora_dropout
# base_model.model.model.encoder.layers.5.self_attn.k_proj.lora_dropout.default
# base_model.model.model.encoder.layers.5.self_attn.k_proj.lora_A
# base_model.model.model.encoder.layers.5.self_attn.k_proj.lora_A.default
# base_model.model.model.encoder.layers.5.self_attn.k_proj.lora_B
# base_model.model.model.encoder.layers.5.self_attn.k_proj.lora_B.default
# base_model.model.model.encoder.layers.5.self_attn.k_proj.lora_embedding_A
# base_model.model.model.encoder.layers.5.self_attn.k_proj.lora_embedding_B
# base_model.model.model.encoder.layers.5.self_attn.k_proj.lora_magnitude_vector
# base_model.model.model.encoder.layers.5.self_attn.v_proj
# base_model.model.model.encoder.layers.5.self_attn.v_proj.base_layer
# base_model.model.model.encoder.layers.5.self_attn.v_proj.lora_dropout
# base_model.model.model.encoder.layers.5.self_attn.v_proj.lora_dropout.default
# base_model.model.model.encoder.layers.5.self_attn.v_proj.lora_A
# base_model.model.model.encoder.layers.5.self_attn.v_proj.lora_A.default
# base_model.model.model.encoder.layers.5.self_attn.v_proj.lora_B
# base_model.model.model.encoder.layers.5.self_attn.v_proj.lora_B.default
# base_model.model.model.encoder.layers.5.self_attn.v_proj.lora_embedding_A
# base_model.model.model.encoder.layers.5.self_attn.v_proj.lora_embedding_B
# base_model.model.model.encoder.layers.5.self_attn.v_proj.lora_magnitude_vector
# base_model.model.model.encoder.layers.5.self_attn.q_proj
# base_model.model.model.encoder.layers.5.self_attn.q_proj.base_layer
# base_model.model.model.encoder.layers.5.self_attn.q_proj.lora_dropout
# base_model.model.model.encoder.layers.5.self_attn.q_proj.lora_dropout.default
# base_model.model.model.encoder.layers.5.self_attn.q_proj.lora_A
# base_model.model.model.encoder.layers.5.self_attn.q_proj.lora_A.default
# base_model.model.model.encoder.layers.5.self_attn.q_proj.lora_B
# base_model.model.model.encoder.layers.5.self_attn.q_proj.lora_B.default
# base_model.model.model.encoder.layers.5.self_attn.q_proj.lora_embedding_A
# base_model.model.model.encoder.layers.5.self_attn.q_proj.lora_embedding_B
# base_model.model.model.encoder.layers.5.self_attn.q_proj.lora_magnitude_vector
# base_model.model.model.encoder.layers.5.self_attn.out_proj
# base_model.model.model.encoder.layers.5.self_attn_layer_norm
# base_model.model.model.encoder.layers.5.activation_fn
# base_model.model.model.encoder.layers.5.fc1
# base_model.model.model.encoder.layers.5.fc2
# base_model.model.model.encoder.layers.5.final_layer_norm
# base_model.model.model.decoder
# base_model.model.model.decoder.embed_positions
# base_model.model.model.decoder.layers
# base_model.model.model.decoder.layers.0
# base_model.model.model.decoder.layers.0.self_attn
# base_model.model.model.decoder.layers.0.self_attn.k_proj
# base_model.model.model.decoder.layers.0.self_attn.k_proj.base_layer
# base_model.model.model.decoder.layers.0.self_attn.k_proj.lora_dropout
# base_model.model.model.decoder.layers.0.self_attn.k_proj.lora_dropout.default
# base_model.model.model.decoder.layers.0.self_attn.k_proj.lora_A
# base_model.model.model.decoder.layers.0.self_attn.k_proj.lora_A.default
# base_model.model.model.decoder.layers.0.self_attn.k_proj.lora_B
# base_model.model.model.decoder.layers.0.self_attn.k_proj.lora_B.default
# base_model.model.model.decoder.layers.0.self_attn.k_proj.lora_embedding_A
# base_model.model.model.decoder.layers.0.self_attn.k_proj.lora_embedding_B
# base_model.model.model.decoder.layers.0.self_attn.k_proj.lora_magnitude_vector
# base_model.model.model.decoder.layers.0.self_attn.v_proj
# base_model.model.model.decoder.layers.0.self_attn.v_proj.base_layer
# base_model.model.model.decoder.layers.0.self_attn.v_proj.lora_dropout
# base_model.model.model.decoder.layers.0.self_attn.v_proj.lora_dropout.default
# base_model.model.model.decoder.layers.0.self_attn.v_proj.lora_A
# base_model.model.model.decoder.layers.0.self_attn.v_proj.lora_A.default
# base_model.model.model.decoder.layers.0.self_attn.v_proj.lora_B
# base_model.model.model.decoder.layers.0.self_attn.v_proj.lora_B.default
# base_model.model.model.decoder.layers.0.self_attn.v_proj.lora_embedding_A
# base_model.model.model.decoder.layers.0.self_attn.v_proj.lora_embedding_B
# base_model.model.model.decoder.layers.0.self_attn.v_proj.lora_magnitude_vector
# base_model.model.model.decoder.layers.0.self_attn.q_proj
# base_model.model.model.decoder.layers.0.self_attn.q_proj.base_layer
# base_model.model.model.decoder.layers.0.self_attn.q_proj.lora_dropout
# base_model.model.model.decoder.layers.0.self_attn.q_proj.lora_dropout.default
# base_model.model.model.decoder.layers.0.self_attn.q_proj.lora_A
# base_model.model.model.decoder.layers.0.self_attn.q_proj.lora_A.default
# base_model.model.model.decoder.layers.0.self_attn.q_proj.lora_B
# base_model.model.model.decoder.layers.0.self_attn.q_proj.lora_B.default
# base_model.model.model.decoder.layers.0.self_attn.q_proj.lora_embedding_A
# base_model.model.model.decoder.layers.0.self_attn.q_proj.lora_embedding_B
# base_model.model.model.decoder.layers.0.self_attn.q_proj.lora_magnitude_vector
# base_model.model.model.decoder.layers.0.self_attn.out_proj
# base_model.model.model.decoder.layers.0.activation_fn
# base_model.model.model.decoder.layers.0.self_attn_layer_norm
# base_model.model.model.decoder.layers.0.encoder_attn
# base_model.model.model.decoder.layers.0.encoder_attn.k_proj
# base_model.model.model.decoder.layers.0.encoder_attn.k_proj.base_layer
# base_model.model.model.decoder.layers.0.encoder_attn.k_proj.lora_dropout
# base_model.model.model.decoder.layers.0.encoder_attn.k_proj.lora_dropout.default
# base_model.model.model.decoder.layers.0.encoder_attn.k_proj.lora_A
# base_model.model.model.decoder.layers.0.encoder_attn.k_proj.lora_A.default
# base_model.model.model.decoder.layers.0.encoder_attn.k_proj.lora_B
# base_model.model.model.decoder.layers.0.encoder_attn.k_proj.lora_B.default
# base_model.model.model.decoder.layers.0.encoder_attn.k_proj.lora_embedding_A
# base_model.model.model.decoder.layers.0.encoder_attn.k_proj.lora_embedding_B
# base_model.model.model.decoder.layers.0.encoder_attn.k_proj.lora_magnitude_vector
# base_model.model.model.decoder.layers.0.encoder_attn.v_proj
# base_model.model.model.decoder.layers.0.encoder_attn.v_proj.base_layer
# base_model.model.model.decoder.layers.0.encoder_attn.v_proj.lora_dropout
# base_model.model.model.decoder.layers.0.encoder_attn.v_proj.lora_dropout.default
# base_model.model.model.decoder.layers.0.encoder_attn.v_proj.lora_A
# base_model.model.model.decoder.layers.0.encoder_attn.v_proj.lora_A.default
# base_model.model.model.decoder.layers.0.encoder_attn.v_proj.lora_B
# base_model.model.model.decoder.layers.0.encoder_attn.v_proj.lora_B.default
# base_model.model.model.decoder.layers.0.encoder_attn.v_proj.lora_embedding_A
# base_model.model.model.decoder.layers.0.encoder_attn.v_proj.lora_embedding_B
# base_model.model.model.decoder.layers.0.encoder_attn.v_proj.lora_magnitude_vector
# base_model.model.model.decoder.layers.0.encoder_attn.q_proj
# base_model.model.model.decoder.layers.0.encoder_attn.q_proj.base_layer
# base_model.model.model.decoder.layers.0.encoder_attn.q_proj.lora_dropout
# base_model.model.model.decoder.layers.0.encoder_attn.q_proj.lora_dropout.default
# base_model.model.model.decoder.layers.0.encoder_attn.q_proj.lora_A
# base_model.model.model.decoder.layers.0.encoder_attn.q_proj.lora_A.default
# base_model.model.model.decoder.layers.0.encoder_attn.q_proj.lora_B
# base_model.model.model.decoder.layers.0.encoder_attn.q_proj.lora_B.default
# base_model.model.model.decoder.layers.0.encoder_attn.q_proj.lora_embedding_A
# base_model.model.model.decoder.layers.0.encoder_attn.q_proj.lora_embedding_B
# base_model.model.model.decoder.layers.0.encoder_attn.q_proj.lora_magnitude_vector
# base_model.model.model.decoder.layers.0.encoder_attn.out_proj
# base_model.model.model.decoder.layers.0.encoder_attn_layer_norm
# base_model.model.model.decoder.layers.0.fc1
# base_model.model.model.decoder.layers.0.fc2
# base_model.model.model.decoder.layers.0.final_layer_norm
# base_model.model.model.decoder.layers.1
# base_model.model.model.decoder.layers.1.self_attn
# base_model.model.model.decoder.layers.1.self_attn.k_proj
# base_model.model.model.decoder.layers.1.self_attn.k_proj.base_layer
# base_model.model.model.decoder.layers.1.self_attn.k_proj.lora_dropout
# base_model.model.model.decoder.layers.1.self_attn.k_proj.lora_dropout.default
# base_model.model.model.decoder.layers.1.self_attn.k_proj.lora_A
# base_model.model.model.decoder.layers.1.self_attn.k_proj.lora_A.default
# base_model.model.model.decoder.layers.1.self_attn.k_proj.lora_B
# base_model.model.model.decoder.layers.1.self_attn.k_proj.lora_B.default
# base_model.model.model.decoder.layers.1.self_attn.k_proj.lora_embedding_A
# base_model.model.model.decoder.layers.1.self_attn.k_proj.lora_embedding_B
# base_model.model.model.decoder.layers.1.self_attn.k_proj.lora_magnitude_vector
# base_model.model.model.decoder.layers.1.self_attn.v_proj
# base_model.model.model.decoder.layers.1.self_attn.v_proj.base_layer
# base_model.model.model.decoder.layers.1.self_attn.v_proj.lora_dropout
# base_model.model.model.decoder.layers.1.self_attn.v_proj.lora_dropout.default
# base_model.model.model.decoder.layers.1.self_attn.v_proj.lora_A
# base_model.model.model.decoder.layers.1.self_attn.v_proj.lora_A.default
# base_model.model.model.decoder.layers.1.self_attn.v_proj.lora_B
# base_model.model.model.decoder.layers.1.self_attn.v_proj.lora_B.default
# base_model.model.model.decoder.layers.1.self_attn.v_proj.lora_embedding_A
# base_model.model.model.decoder.layers.1.self_attn.v_proj.lora_embedding_B
# base_model.model.model.decoder.layers.1.self_attn.v_proj.lora_magnitude_vector
# base_model.model.model.decoder.layers.1.self_attn.q_proj
# base_model.model.model.decoder.layers.1.self_attn.q_proj.base_layer
# base_model.model.model.decoder.layers.1.self_attn.q_proj.lora_dropout
# base_model.model.model.decoder.layers.1.self_attn.q_proj.lora_dropout.default
# base_model.model.model.decoder.layers.1.self_attn.q_proj.lora_A
# base_model.model.model.decoder.layers.1.self_attn.q_proj.lora_A.default
# base_model.model.model.decoder.layers.1.self_attn.q_proj.lora_B
# base_model.model.model.decoder.layers.1.self_attn.q_proj.lora_B.default
# base_model.model.model.decoder.layers.1.self_attn.q_proj.lora_embedding_A
# base_model.model.model.decoder.layers.1.self_attn.q_proj.lora_embedding_B
# base_model.model.model.decoder.layers.1.self_attn.q_proj.lora_magnitude_vector
# base_model.model.model.decoder.layers.1.self_attn.out_proj
# base_model.model.model.decoder.layers.1.activation_fn
# base_model.model.model.decoder.layers.1.self_attn_layer_norm
# base_model.model.model.decoder.layers.1.encoder_attn
# base_model.model.model.decoder.layers.1.encoder_attn.k_proj
# base_model.model.model.decoder.layers.1.encoder_attn.k_proj.base_layer
# base_model.model.model.decoder.layers.1.encoder_attn.k_proj.lora_dropout
# base_model.model.model.decoder.layers.1.encoder_attn.k_proj.lora_dropout.default
# base_model.model.model.decoder.layers.1.encoder_attn.k_proj.lora_A
# base_model.model.model.decoder.layers.1.encoder_attn.k_proj.lora_A.default
# base_model.model.model.decoder.layers.1.encoder_attn.k_proj.lora_B
# base_model.model.model.decoder.layers.1.encoder_attn.k_proj.lora_B.default
# base_model.model.model.decoder.layers.1.encoder_attn.k_proj.lora_embedding_A
# base_model.model.model.decoder.layers.1.encoder_attn.k_proj.lora_embedding_B
# base_model.model.model.decoder.layers.1.encoder_attn.k_proj.lora_magnitude_vector
# base_model.model.model.decoder.layers.1.encoder_attn.v_proj
# base_model.model.model.decoder.layers.1.encoder_attn.v_proj.base_layer
# base_model.model.model.decoder.layers.1.encoder_attn.v_proj.lora_dropout
# base_model.model.model.decoder.layers.1.encoder_attn.v_proj.lora_dropout.default
# base_model.model.model.decoder.layers.1.encoder_attn.v_proj.lora_A
# base_model.model.model.decoder.layers.1.encoder_attn.v_proj.lora_A.default
# base_model.model.model.decoder.layers.1.encoder_attn.v_proj.lora_B
# base_model.model.model.decoder.layers.1.encoder_attn.v_proj.lora_B.default
# base_model.model.model.decoder.layers.1.encoder_attn.v_proj.lora_embedding_A
# base_model.model.model.decoder.layers.1.encoder_attn.v_proj.lora_embedding_B
# base_model.model.model.decoder.layers.1.encoder_attn.v_proj.lora_magnitude_vector
# base_model.model.model.decoder.layers.1.encoder_attn.q_proj
# base_model.model.model.decoder.layers.1.encoder_attn.q_proj.base_layer
# base_model.model.model.decoder.layers.1.encoder_attn.q_proj.lora_dropout
# base_model.model.model.decoder.layers.1.encoder_attn.q_proj.lora_dropout.default
# base_model.model.model.decoder.layers.1.encoder_attn.q_proj.lora_A
# base_model.model.model.decoder.layers.1.encoder_attn.q_proj.lora_A.default
# base_model.model.model.decoder.layers.1.encoder_attn.q_proj.lora_B
# base_model.model.model.decoder.layers.1.encoder_attn.q_proj.lora_B.default
# base_model.model.model.decoder.layers.1.encoder_attn.q_proj.lora_embedding_A
# base_model.model.model.decoder.layers.1.encoder_attn.q_proj.lora_embedding_B
# base_model.model.model.decoder.layers.1.encoder_attn.q_proj.lora_magnitude_vector
# base_model.model.model.decoder.layers.1.encoder_attn.out_proj
# base_model.model.model.decoder.layers.1.encoder_attn_layer_norm
# base_model.model.model.decoder.layers.1.fc1
# base_model.model.model.decoder.layers.1.fc2
# base_model.model.model.decoder.layers.1.final_layer_norm
# base_model.model.model.decoder.layers.2
# base_model.model.model.decoder.layers.2.self_attn
# base_model.model.model.decoder.layers.2.self_attn.k_proj
# base_model.model.model.decoder.layers.2.self_attn.k_proj.base_layer
# base_model.model.model.decoder.layers.2.self_attn.k_proj.lora_dropout
# base_model.model.model.decoder.layers.2.self_attn.k_proj.lora_dropout.default
# base_model.model.model.decoder.layers.2.self_attn.k_proj.lora_A
# base_model.model.model.decoder.layers.2.self_attn.k_proj.lora_A.default
# base_model.model.model.decoder.layers.2.self_attn.k_proj.lora_B
# base_model.model.model.decoder.layers.2.self_attn.k_proj.lora_B.default
# base_model.model.model.decoder.layers.2.self_attn.k_proj.lora_embedding_A
# base_model.model.model.decoder.layers.2.self_attn.k_proj.lora_embedding_B
# base_model.model.model.decoder.layers.2.self_attn.k_proj.lora_magnitude_vector
# base_model.model.model.decoder.layers.2.self_attn.v_proj
# base_model.model.model.decoder.layers.2.self_attn.v_proj.base_layer
# base_model.model.model.decoder.layers.2.self_attn.v_proj.lora_dropout
# base_model.model.model.decoder.layers.2.self_attn.v_proj.lora_dropout.default
# base_model.model.model.decoder.layers.2.self_attn.v_proj.lora_A
# base_model.model.model.decoder.layers.2.self_attn.v_proj.lora_A.default
# base_model.model.model.decoder.layers.2.self_attn.v_proj.lora_B
# base_model.model.model.decoder.layers.2.self_attn.v_proj.lora_B.default
# base_model.model.model.decoder.layers.2.self_attn.v_proj.lora_embedding_A
# base_model.model.model.decoder.layers.2.self_attn.v_proj.lora_embedding_B
# base_model.model.model.decoder.layers.2.self_attn.v_proj.lora_magnitude_vector
# base_model.model.model.decoder.layers.2.self_attn.q_proj
# base_model.model.model.decoder.layers.2.self_attn.q_proj.base_layer
# base_model.model.model.decoder.layers.2.self_attn.q_proj.lora_dropout
# base_model.model.model.decoder.layers.2.self_attn.q_proj.lora_dropout.default
# base_model.model.model.decoder.layers.2.self_attn.q_proj.lora_A
# base_model.model.model.decoder.layers.2.self_attn.q_proj.lora_A.default
# base_model.model.model.decoder.layers.2.self_attn.q_proj.lora_B
# base_model.model.model.decoder.layers.2.self_attn.q_proj.lora_B.default
# base_model.model.model.decoder.layers.2.self_attn.q_proj.lora_embedding_A
# base_model.model.model.decoder.layers.2.self_attn.q_proj.lora_embedding_B
# base_model.model.model.decoder.layers.2.self_attn.q_proj.lora_magnitude_vector
# base_model.model.model.decoder.layers.2.self_attn.out_proj
# base_model.model.model.decoder.layers.2.activation_fn
# base_model.model.model.decoder.layers.2.self_attn_layer_norm
# base_model.model.model.decoder.layers.2.encoder_attn
# base_model.model.model.decoder.layers.2.encoder_attn.k_proj
# base_model.model.model.decoder.layers.2.encoder_attn.k_proj.base_layer
# base_model.model.model.decoder.layers.2.encoder_attn.k_proj.lora_dropout
# base_model.model.model.decoder.layers.2.encoder_attn.k_proj.lora_dropout.default
# base_model.model.model.decoder.layers.2.encoder_attn.k_proj.lora_A
# base_model.model.model.decoder.layers.2.encoder_attn.k_proj.lora_A.default
# base_model.model.model.decoder.layers.2.encoder_attn.k_proj.lora_B
# base_model.model.model.decoder.layers.2.encoder_attn.k_proj.lora_B.default
# base_model.model.model.decoder.layers.2.encoder_attn.k_proj.lora_embedding_A
# base_model.model.model.decoder.layers.2.encoder_attn.k_proj.lora_embedding_B
# base_model.model.model.decoder.layers.2.encoder_attn.k_proj.lora_magnitude_vector
# base_model.model.model.decoder.layers.2.encoder_attn.v_proj
# base_model.model.model.decoder.layers.2.encoder_attn.v_proj.base_layer
# base_model.model.model.decoder.layers.2.encoder_attn.v_proj.lora_dropout
# base_model.model.model.decoder.layers.2.encoder_attn.v_proj.lora_dropout.default
# base_model.model.model.decoder.layers.2.encoder_attn.v_proj.lora_A
# base_model.model.model.decoder.layers.2.encoder_attn.v_proj.lora_A.default
# base_model.model.model.decoder.layers.2.encoder_attn.v_proj.lora_B
# base_model.model.model.decoder.layers.2.encoder_attn.v_proj.lora_B.default
# base_model.model.model.decoder.layers.2.encoder_attn.v_proj.lora_embedding_A
# base_model.model.model.decoder.layers.2.encoder_attn.v_proj.lora_embedding_B
# base_model.model.model.decoder.layers.2.encoder_attn.v_proj.lora_magnitude_vector
# base_model.model.model.decoder.layers.2.encoder_attn.q_proj
# base_model.model.model.decoder.layers.2.encoder_attn.q_proj.base_layer
# base_model.model.model.decoder.layers.2.encoder_attn.q_proj.lora_dropout
# base_model.model.model.decoder.layers.2.encoder_attn.q_proj.lora_dropout.default
# base_model.model.model.decoder.layers.2.encoder_attn.q_proj.lora_A
# base_model.model.model.decoder.layers.2.encoder_attn.q_proj.lora_A.default
# base_model.model.model.decoder.layers.2.encoder_attn.q_proj.lora_B
# base_model.model.model.decoder.layers.2.encoder_attn.q_proj.lora_B.default
# base_model.model.model.decoder.layers.2.encoder_attn.q_proj.lora_embedding_A
# base_model.model.model.decoder.layers.2.encoder_attn.q_proj.lora_embedding_B
# base_model.model.model.decoder.layers.2.encoder_attn.q_proj.lora_magnitude_vector
# base_model.model.model.decoder.layers.2.encoder_attn.out_proj
# base_model.model.model.decoder.layers.2.encoder_attn_layer_norm
# base_model.model.model.decoder.layers.2.fc1
# base_model.model.model.decoder.layers.2.fc2
# base_model.model.model.decoder.layers.2.final_layer_norm
# base_model.model.model.decoder.layers.3
# base_model.model.model.decoder.layers.3.self_attn
# base_model.model.model.decoder.layers.3.self_attn.k_proj
# base_model.model.model.decoder.layers.3.self_attn.k_proj.base_layer
# base_model.model.model.decoder.layers.3.self_attn.k_proj.lora_dropout
# base_model.model.model.decoder.layers.3.self_attn.k_proj.lora_dropout.default
# base_model.model.model.decoder.layers.3.self_attn.k_proj.lora_A
# base_model.model.model.decoder.layers.3.self_attn.k_proj.lora_A.default
# base_model.model.model.decoder.layers.3.self_attn.k_proj.lora_B
# base_model.model.model.decoder.layers.3.self_attn.k_proj.lora_B.default
# base_model.model.model.decoder.layers.3.self_attn.k_proj.lora_embedding_A
# base_model.model.model.decoder.layers.3.self_attn.k_proj.lora_embedding_B
# base_model.model.model.decoder.layers.3.self_attn.k_proj.lora_magnitude_vector
# base_model.model.model.decoder.layers.3.self_attn.v_proj
# base_model.model.model.decoder.layers.3.self_attn.v_proj.base_layer
# base_model.model.model.decoder.layers.3.self_attn.v_proj.lora_dropout
# base_model.model.model.decoder.layers.3.self_attn.v_proj.lora_dropout.default
# base_model.model.model.decoder.layers.3.self_attn.v_proj.lora_A
# base_model.model.model.decoder.layers.3.self_attn.v_proj.lora_A.default
# base_model.model.model.decoder.layers.3.self_attn.v_proj.lora_B
# base_model.model.model.decoder.layers.3.self_attn.v_proj.lora_B.default
# base_model.model.model.decoder.layers.3.self_attn.v_proj.lora_embedding_A
# base_model.model.model.decoder.layers.3.self_attn.v_proj.lora_embedding_B
# base_model.model.model.decoder.layers.3.self_attn.v_proj.lora_magnitude_vector
# base_model.model.model.decoder.layers.3.self_attn.q_proj
# base_model.model.model.decoder.layers.3.self_attn.q_proj.base_layer
# base_model.model.model.decoder.layers.3.self_attn.q_proj.lora_dropout
# base_model.model.model.decoder.layers.3.self_attn.q_proj.lora_dropout.default
# base_model.model.model.decoder.layers.3.self_attn.q_proj.lora_A
# base_model.model.model.decoder.layers.3.self_attn.q_proj.lora_A.default
# base_model.model.model.decoder.layers.3.self_attn.q_proj.lora_B
# base_model.model.model.decoder.layers.3.self_attn.q_proj.lora_B.default
# base_model.model.model.decoder.layers.3.self_attn.q_proj.lora_embedding_A
# base_model.model.model.decoder.layers.3.self_attn.q_proj.lora_embedding_B
# base_model.model.model.decoder.layers.3.self_attn.q_proj.lora_magnitude_vector
# base_model.model.model.decoder.layers.3.self_attn.out_proj
# base_model.model.model.decoder.layers.3.activation_fn
# base_model.model.model.decoder.layers.3.self_attn_layer_norm
# base_model.model.model.decoder.layers.3.encoder_attn
# base_model.model.model.decoder.layers.3.encoder_attn.k_proj
# base_model.model.model.decoder.layers.3.encoder_attn.k_proj.base_layer
# base_model.model.model.decoder.layers.3.encoder_attn.k_proj.lora_dropout
# base_model.model.model.decoder.layers.3.encoder_attn.k_proj.lora_dropout.default
# base_model.model.model.decoder.layers.3.encoder_attn.k_proj.lora_A
# base_model.model.model.decoder.layers.3.encoder_attn.k_proj.lora_A.default
# base_model.model.model.decoder.layers.3.encoder_attn.k_proj.lora_B
# base_model.model.model.decoder.layers.3.encoder_attn.k_proj.lora_B.default
# base_model.model.model.decoder.layers.3.encoder_attn.k_proj.lora_embedding_A
# base_model.model.model.decoder.layers.3.encoder_attn.k_proj.lora_embedding_B
# base_model.model.model.decoder.layers.3.encoder_attn.k_proj.lora_magnitude_vector
# base_model.model.model.decoder.layers.3.encoder_attn.v_proj
# base_model.model.model.decoder.layers.3.encoder_attn.v_proj.base_layer
# base_model.model.model.decoder.layers.3.encoder_attn.v_proj.lora_dropout
# base_model.model.model.decoder.layers.3.encoder_attn.v_proj.lora_dropout.default
# base_model.model.model.decoder.layers.3.encoder_attn.v_proj.lora_A
# base_model.model.model.decoder.layers.3.encoder_attn.v_proj.lora_A.default
# base_model.model.model.decoder.layers.3.encoder_attn.v_proj.lora_B
# base_model.model.model.decoder.layers.3.encoder_attn.v_proj.lora_B.default
# base_model.model.model.decoder.layers.3.encoder_attn.v_proj.lora_embedding_A
# base_model.model.model.decoder.layers.3.encoder_attn.v_proj.lora_embedding_B
# base_model.model.model.decoder.layers.3.encoder_attn.v_proj.lora_magnitude_vector
# base_model.model.model.decoder.layers.3.encoder_attn.q_proj
# base_model.model.model.decoder.layers.3.encoder_attn.q_proj.base_layer
# base_model.model.model.decoder.layers.3.encoder_attn.q_proj.lora_dropout
# base_model.model.model.decoder.layers.3.encoder_attn.q_proj.lora_dropout.default
# base_model.model.model.decoder.layers.3.encoder_attn.q_proj.lora_A
# base_model.model.model.decoder.layers.3.encoder_attn.q_proj.lora_A.default
# base_model.model.model.decoder.layers.3.encoder_attn.q_proj.lora_B
# base_model.model.model.decoder.layers.3.encoder_attn.q_proj.lora_B.default
# base_model.model.model.decoder.layers.3.encoder_attn.q_proj.lora_embedding_A
# base_model.model.model.decoder.layers.3.encoder_attn.q_proj.lora_embedding_B
# base_model.model.model.decoder.layers.3.encoder_attn.q_proj.lora_magnitude_vector
# base_model.model.model.decoder.layers.3.encoder_attn.out_proj
# base_model.model.model.decoder.layers.3.encoder_attn_layer_norm
# base_model.model.model.decoder.layers.3.fc1
# base_model.model.model.decoder.layers.3.fc2
# base_model.model.model.decoder.layers.3.final_layer_norm
# base_model.model.model.decoder.layers.4
# base_model.model.model.decoder.layers.4.self_attn
# base_model.model.model.decoder.layers.4.self_attn.k_proj
# base_model.model.model.decoder.layers.4.self_attn.k_proj.base_layer
# base_model.model.model.decoder.layers.4.self_attn.k_proj.lora_dropout
# base_model.model.model.decoder.layers.4.self_attn.k_proj.lora_dropout.default
# base_model.model.model.decoder.layers.4.self_attn.k_proj.lora_A
# base_model.model.model.decoder.layers.4.self_attn.k_proj.lora_A.default
# base_model.model.model.decoder.layers.4.self_attn.k_proj.lora_B
# base_model.model.model.decoder.layers.4.self_attn.k_proj.lora_B.default
# base_model.model.model.decoder.layers.4.self_attn.k_proj.lora_embedding_A
# base_model.model.model.decoder.layers.4.self_attn.k_proj.lora_embedding_B
# base_model.model.model.decoder.layers.4.self_attn.k_proj.lora_magnitude_vector
# base_model.model.model.decoder.layers.4.self_attn.v_proj
# base_model.model.model.decoder.layers.4.self_attn.v_proj.base_layer
# base_model.model.model.decoder.layers.4.self_attn.v_proj.lora_dropout
# base_model.model.model.decoder.layers.4.self_attn.v_proj.lora_dropout.default
# base_model.model.model.decoder.layers.4.self_attn.v_proj.lora_A
# base_model.model.model.decoder.layers.4.self_attn.v_proj.lora_A.default
# base_model.model.model.decoder.layers.4.self_attn.v_proj.lora_B
# base_model.model.model.decoder.layers.4.self_attn.v_proj.lora_B.default
# base_model.model.model.decoder.layers.4.self_attn.v_proj.lora_embedding_A
# base_model.model.model.decoder.layers.4.self_attn.v_proj.lora_embedding_B
# base_model.model.model.decoder.layers.4.self_attn.v_proj.lora_magnitude_vector
# base_model.model.model.decoder.layers.4.self_attn.q_proj
# base_model.model.model.decoder.layers.4.self_attn.q_proj.base_layer
# base_model.model.model.decoder.layers.4.self_attn.q_proj.lora_dropout
# base_model.model.model.decoder.layers.4.self_attn.q_proj.lora_dropout.default
# base_model.model.model.decoder.layers.4.self_attn.q_proj.lora_A
# base_model.model.model.decoder.layers.4.self_attn.q_proj.lora_A.default
# base_model.model.model.decoder.layers.4.self_attn.q_proj.lora_B
# base_model.model.model.decoder.layers.4.self_attn.q_proj.lora_B.default
# base_model.model.model.decoder.layers.4.self_attn.q_proj.lora_embedding_A
# base_model.model.model.decoder.layers.4.self_attn.q_proj.lora_embedding_B
# base_model.model.model.decoder.layers.4.self_attn.q_proj.lora_magnitude_vector
# base_model.model.model.decoder.layers.4.self_attn.out_proj
# base_model.model.model.decoder.layers.4.activation_fn
# base_model.model.model.decoder.layers.4.self_attn_layer_norm
# base_model.model.model.decoder.layers.4.encoder_attn
# base_model.model.model.decoder.layers.4.encoder_attn.k_proj
# base_model.model.model.decoder.layers.4.encoder_attn.k_proj.base_layer
# base_model.model.model.decoder.layers.4.encoder_attn.k_proj.lora_dropout
# base_model.model.model.decoder.layers.4.encoder_attn.k_proj.lora_dropout.default
# base_model.model.model.decoder.layers.4.encoder_attn.k_proj.lora_A
# base_model.model.model.decoder.layers.4.encoder_attn.k_proj.lora_A.default
# base_model.model.model.decoder.layers.4.encoder_attn.k_proj.lora_B
# base_model.model.model.decoder.layers.4.encoder_attn.k_proj.lora_B.default
# base_model.model.model.decoder.layers.4.encoder_attn.k_proj.lora_embedding_A
# base_model.model.model.decoder.layers.4.encoder_attn.k_proj.lora_embedding_B
# base_model.model.model.decoder.layers.4.encoder_attn.k_proj.lora_magnitude_vector
# base_model.model.model.decoder.layers.4.encoder_attn.v_proj
# base_model.model.model.decoder.layers.4.encoder_attn.v_proj.base_layer
# base_model.model.model.decoder.layers.4.encoder_attn.v_proj.lora_dropout
# base_model.model.model.decoder.layers.4.encoder_attn.v_proj.lora_dropout.default
# base_model.model.model.decoder.layers.4.encoder_attn.v_proj.lora_A
# base_model.model.model.decoder.layers.4.encoder_attn.v_proj.lora_A.default
# base_model.model.model.decoder.layers.4.encoder_attn.v_proj.lora_B
# base_model.model.model.decoder.layers.4.encoder_attn.v_proj.lora_B.default
# base_model.model.model.decoder.layers.4.encoder_attn.v_proj.lora_embedding_A
# base_model.model.model.decoder.layers.4.encoder_attn.v_proj.lora_embedding_B
# base_model.model.model.decoder.layers.4.encoder_attn.v_proj.lora_magnitude_vector
# base_model.model.model.decoder.layers.4.encoder_attn.q_proj
# base_model.model.model.decoder.layers.4.encoder_attn.q_proj.base_layer
# base_model.model.model.decoder.layers.4.encoder_attn.q_proj.lora_dropout
# base_model.model.model.decoder.layers.4.encoder_attn.q_proj.lora_dropout.default
# base_model.model.model.decoder.layers.4.encoder_attn.q_proj.lora_A
# base_model.model.model.decoder.layers.4.encoder_attn.q_proj.lora_A.default
# base_model.model.model.decoder.layers.4.encoder_attn.q_proj.lora_B
# base_model.model.model.decoder.layers.4.encoder_attn.q_proj.lora_B.default
# base_model.model.model.decoder.layers.4.encoder_attn.q_proj.lora_embedding_A
# base_model.model.model.decoder.layers.4.encoder_attn.q_proj.lora_embedding_B
# base_model.model.model.decoder.layers.4.encoder_attn.q_proj.lora_magnitude_vector
# base_model.model.model.decoder.layers.4.encoder_attn.out_proj
# base_model.model.model.decoder.layers.4.encoder_attn_layer_norm
# base_model.model.model.decoder.layers.4.fc1
# base_model.model.model.decoder.layers.4.fc2
# base_model.model.model.decoder.layers.4.final_layer_norm
# base_model.model.model.decoder.layers.5
# base_model.model.model.decoder.layers.5.self_attn
# base_model.model.model.decoder.layers.5.self_attn.k_proj
# base_model.model.model.decoder.layers.5.self_attn.k_proj.base_layer
# base_model.model.model.decoder.layers.5.self_attn.k_proj.lora_dropout
# base_model.model.model.decoder.layers.5.self_attn.k_proj.lora_dropout.default
# base_model.model.model.decoder.layers.5.self_attn.k_proj.lora_A
# base_model.model.model.decoder.layers.5.self_attn.k_proj.lora_A.default
# base_model.model.model.decoder.layers.5.self_attn.k_proj.lora_B
# base_model.model.model.decoder.layers.5.self_attn.k_proj.lora_B.default
# base_model.model.model.decoder.layers.5.self_attn.k_proj.lora_embedding_A
# base_model.model.model.decoder.layers.5.self_attn.k_proj.lora_embedding_B
# base_model.model.model.decoder.layers.5.self_attn.k_proj.lora_magnitude_vector
# base_model.model.model.decoder.layers.5.self_attn.v_proj
# base_model.model.model.decoder.layers.5.self_attn.v_proj.base_layer
# base_model.model.model.decoder.layers.5.self_attn.v_proj.lora_dropout
# base_model.model.model.decoder.layers.5.self_attn.v_proj.lora_dropout.default
# base_model.model.model.decoder.layers.5.self_attn.v_proj.lora_A
# base_model.model.model.decoder.layers.5.self_attn.v_proj.lora_A.default
# base_model.model.model.decoder.layers.5.self_attn.v_proj.lora_B
# base_model.model.model.decoder.layers.5.self_attn.v_proj.lora_B.default
# base_model.model.model.decoder.layers.5.self_attn.v_proj.lora_embedding_A
# base_model.model.model.decoder.layers.5.self_attn.v_proj.lora_embedding_B
# base_model.model.model.decoder.layers.5.self_attn.v_proj.lora_magnitude_vector
# base_model.model.model.decoder.layers.5.self_attn.q_proj
# base_model.model.model.decoder.layers.5.self_attn.q_proj.base_layer
# base_model.model.model.decoder.layers.5.self_attn.q_proj.lora_dropout
# base_model.model.model.decoder.layers.5.self_attn.q_proj.lora_dropout.default
# base_model.model.model.decoder.layers.5.self_attn.q_proj.lora_A
# base_model.model.model.decoder.layers.5.self_attn.q_proj.lora_A.default
# base_model.model.model.decoder.layers.5.self_attn.q_proj.lora_B
# base_model.model.model.decoder.layers.5.self_attn.q_proj.lora_B.default
# base_model.model.model.decoder.layers.5.self_attn.q_proj.lora_embedding_A
# base_model.model.model.decoder.layers.5.self_attn.q_proj.lora_embedding_B
# base_model.model.model.decoder.layers.5.self_attn.q_proj.lora_magnitude_vector
# base_model.model.model.decoder.layers.5.self_attn.out_proj
# base_model.model.model.decoder.layers.5.activation_fn
# base_model.model.model.decoder.layers.5.self_attn_layer_norm
# base_model.model.model.decoder.layers.5.encoder_attn
# base_model.model.model.decoder.layers.5.encoder_attn.k_proj
# base_model.model.model.decoder.layers.5.encoder_attn.k_proj.base_layer
# base_model.model.model.decoder.layers.5.encoder_attn.k_proj.lora_dropout
# base_model.model.model.decoder.layers.5.encoder_attn.k_proj.lora_dropout.default
# base_model.model.model.decoder.layers.5.encoder_attn.k_proj.lora_A
# base_model.model.model.decoder.layers.5.encoder_attn.k_proj.lora_A.default
# base_model.model.model.decoder.layers.5.encoder_attn.k_proj.lora_B
# base_model.model.model.decoder.layers.5.encoder_attn.k_proj.lora_B.default
# base_model.model.model.decoder.layers.5.encoder_attn.k_proj.lora_embedding_A
# base_model.model.model.decoder.layers.5.encoder_attn.k_proj.lora_embedding_B
# base_model.model.model.decoder.layers.5.encoder_attn.k_proj.lora_magnitude_vector
# base_model.model.model.decoder.layers.5.encoder_attn.v_proj
# base_model.model.model.decoder.layers.5.encoder_attn.v_proj.base_layer
# base_model.model.model.decoder.layers.5.encoder_attn.v_proj.lora_dropout
# base_model.model.model.decoder.layers.5.encoder_attn.v_proj.lora_dropout.default
# base_model.model.model.decoder.layers.5.encoder_attn.v_proj.lora_A
# base_model.model.model.decoder.layers.5.encoder_attn.v_proj.lora_A.default
# base_model.model.model.decoder.layers.5.encoder_attn.v_proj.lora_B
# base_model.model.model.decoder.layers.5.encoder_attn.v_proj.lora_B.default
# base_model.model.model.decoder.layers.5.encoder_attn.v_proj.lora_embedding_A
# base_model.model.model.decoder.layers.5.encoder_attn.v_proj.lora_embedding_B
# base_model.model.model.decoder.layers.5.encoder_attn.v_proj.lora_magnitude_vector
# base_model.model.model.decoder.layers.5.encoder_attn.q_proj
# base_model.model.model.decoder.layers.5.encoder_attn.q_proj.base_layer
# base_model.model.model.decoder.layers.5.encoder_attn.q_proj.lora_dropout
# base_model.model.model.decoder.layers.5.encoder_attn.q_proj.lora_dropout.default
# base_model.model.model.decoder.layers.5.encoder_attn.q_proj.lora_A
# base_model.model.model.decoder.layers.5.encoder_attn.q_proj.lora_A.default
# base_model.model.model.decoder.layers.5.encoder_attn.q_proj.lora_B
# base_model.model.model.decoder.layers.5.encoder_attn.q_proj.lora_B.default
# base_model.model.model.decoder.layers.5.encoder_attn.q_proj.lora_embedding_A
# base_model.model.model.decoder.layers.5.encoder_attn.q_proj.lora_embedding_B
# base_model.model.model.decoder.layers.5.encoder_attn.q_proj.lora_magnitude_vector
# base_model.model.model.decoder.layers.5.encoder_attn.out_proj
# base_model.model.model.decoder.layers.5.encoder_attn_layer_norm
# base_model.model.model.decoder.layers.5.fc1
# base_model.model.model.decoder.layers.5.fc2
# base_model.model.model.decoder.layers.5.final_layer_norm
# base_model.model.lm_head

# %%
from peft import LoraConfig, get_peft_model, prepare_model_for_kbit_training

lora_config = LoraConfig(
    r=8,  
    lora_alpha=32,  
    target_modules=["q_proj", "v_proj", "k_proj"],  
    lora_dropout=0.1, 
    bias="none",  
    task_type="SEQ_2_SEQ_LM" 
)

model = get_peft_model(model, lora_config)

model = prepare_model_for_kbit_training(model)

# %%
from transformers import Seq2SeqTrainingArguments,Seq2SeqTrainer

training_args = Seq2SeqTrainingArguments(
    output_dir="marianmt-lora-finetuned",
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=10, 
    logging_dir="./logs",
    logging_steps=100,
    save_steps=500,
    evaluation_strategy="steps",
    eval_steps=500,
    save_total_limit=2,
    remove_unused_columns=False,
    fp16=True,
    push_to_hub=False,
)
# Out:
# c:\Users\UYW1KOR\AppData\Local\anaconda3\envs\projects\Lib\site-packages\transformers\training_args.py:1594: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %%
trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_train,
    eval_dataset=tokenized_test,
    tokenizer=tokenizer,
)

trainer.train()
# Out:
# C:\Users\UYW1KOR\AppData\Local\Temp\ipykernel_27076\1636099230.py:1: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Seq2SeqTrainer.__init__`. Use `processing_class` instead.
#   trainer = Seq2SeqTrainer(
# No label_names provided for model class `PeftModelForSeq2SeqLM`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 9
#       1 trainer = Seq2SeqTrainer(
#       2     model=model,
#       3     args=training_args,
#    (...)
#       6     tokenizer=tokenizer,
#       7 )
# ----> 9 trainer.train()
#
# File c:\Users\UYW1KOR\AppData\Local\anaconda3\envs\projects\Lib\site-packages\transformers\trainer.py:2241, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2239         hf_hub_utils.enable_progress_bars()
#    2240 else:
# -> 2241     return inner_training_loop(
#    2242         args=args,
#    2243         resume_from_checkpoint=resume_from_checkpoint,
#    2244         trial=trial,
#    2245         ignore_keys_for_eval=ignore_keys_for_eval,
#    2246     )
#
# File c:\Users\UYW1KOR\AppData\Local\anaconda3\envs\projects\Lib\site-packages\transformers\trainer.py:2500, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2498 update_step += 1
#    2499 num_batches = args.gradient_accumulation_steps if update_step != (total_updates - 1) else remainder
# -> 2500 batch_samples, num_items_in_batch = self.get_batch_samples(epoch_iterator, num_batches)
#    2501 for i, inputs in enumerate(batch_samples):
#    2502     step += 1
#
# File c:\Users\UYW1KOR\AppData\Local\anaconda3\envs\projects\Lib\site-packages\transformers\trainer.py:5180, in Trainer.get_batch_samples(self, epoch_iterator, num_batches)
#    5178 for _ in range(num_batches):
#    5179     try:
# -> 5180         batch_samples += [next(epoch_iterator)]
#    5181     except StopIteration:
#    5182         break
#
# File c:\Users\UYW1KOR\AppData\Local\anaconda3\envs\projects\Lib\site-packages\accelerate\data_loader.py:550, in DataLoaderShard.__iter__(self)
#     548 # We iterate one batch ahead to check when we are at the end
#     549 try:
# --> 550     current_batch = next(dataloader_iter)
#     551 except StopIteration:
#     552     yield
#
# File c:\Users\UYW1KOR\AppData\Local\anaconda3\envs\projects\Lib\site-packages\torch\utils\data\dataloader.py:701, in _BaseDataLoaderIter.__next__(self)
#     698 if self._sampler_iter is None:
#     699     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700     self._reset()  # type: ignore[call-arg]
# --> 701 data = self._next_data()
#     702 self._num_yielded += 1
#     703 if (
#     704     self._dataset_kind == _DatasetKind.Iterable
#     705     and self._IterableDataset_len_called is not None
#     706     and self._num_yielded > self._IterableDataset_len_called
#     707 ):
#
# File c:\Users\UYW1KOR\AppData\Local\anaconda3\envs\projects\Lib\site-packages\torch\utils\data\dataloader.py:757, in _SingleProcessDataLoaderIter._next_data(self)
#     755 def _next_data(self):
#     756     index = self._next_index()  # may raise StopIteration
# --> 757     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     758     if self._pin_memory:
#     759         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\UYW1KOR\AppData\Local\anaconda3\envs\projects\Lib\site-packages\torch\utils\data\_utils\fetch.py:55, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
# ---> 55 return self.collate_fn(data)
#
# File c:\Users\UYW1KOR\AppData\Local\anaconda3\envs\projects\Lib\site-packages\transformers\data\data_collator.py:271, in DataCollatorWithPadding.__call__(self, features)
#     270 def __call__(self, features: List[Dict[str, Any]]) -> Dict[str, Any]:
# --> 271     batch = pad_without_fast_tokenizer_warning(
#     272         self.tokenizer,
#     273         features,
#     274         padding=self.padding,
#     275         max_length=self.max_length,
#     276         pad_to_multiple_of=self.pad_to_multiple_of,
#     277         return_tensors=self.return_tensors,
#     278     )
#     279     if "label" in batch:
#     280         batch["labels"] = batch["label"]
#
# File c:\Users\UYW1KOR\AppData\Local\anaconda3\envs\projects\Lib\site-packages\transformers\data\data_collator.py:66, in pad_without_fast_tokenizer_warning(tokenizer, *pad_args, **pad_kwargs)
#      63 tokenizer.deprecation_warnings["Asking-to-pad-a-fast-tokenizer"] = True
#      65 try:
# ---> 66     padded = tokenizer.pad(*pad_args, **pad_kwargs)
#      67 finally:
#      68     # Restore the state of the warning.
#      69     tokenizer.deprecation_warnings["Asking-to-pad-a-fast-tokenizer"] = warning_state
#
# File c:\Users\UYW1KOR\AppData\Local\anaconda3\envs\projects\Lib\site-packages\transformers\tokenization_utils_base.py:3314, in PreTrainedTokenizerBase.pad(self, encoded_inputs, padding, max_length, pad_to_multiple_of, padding_side, return_attention_mask, return_tensors, verbose)
#    3312 # The model's main input name, usually `input_ids`, has been passed for padding
#    3313 if self.model_input_names[0] not in encoded_inputs:
# -> 3314     raise ValueError(
#    3315         "You should supply an encoding or a list of encodings to this method "
#    3316         f"that includes {self.model_input_names[0]}, but you provided {list(encoded_inputs.keys())}"
#    3317     )
#    3319 required_input = encoded_inputs[self.model_input_names[0]]
#    3321 if required_input is None or (isinstance(required_input, Sized) and len(required_input) == 0):
#
# ValueError: You should supply an encoding or a list of encodings to this method that includes input_ids, but you provided ['inpu_ids', 'attention_mask', 'labels']

# %%
model.save_pretrained("marianmt-lora-finetuned")
tokenizer.save_pretrained("marianmt-lora-finetuned")

# %%
from datasets import load_dataset

# Load your dataset
data = load_dataset("csv", data_files="eng_-french.csv")

# Preprocess the dataset
def preprocess_function(examples):
    inputs = [f"translate English to French: {text}" for text in examples["English words/sentences"]]
    targets = examples["French words/sentences"]
    return tokenizer(inputs, text_target=targets, max_length=128, truncation=True)

tokenized_data = preprocess_function(data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 12
#       9     targets = examples["French words/sentences"]
#      10     return tokenizer(inputs, text_target=targets, max_length=128, truncation=True)
# ---> 12 tokenized_data = preprocess_function(data)
#
# Cell In[5], line 8, in preprocess_function(examples)
#       7 def preprocess_function(examples):
# ----> 8     inputs = [f"translate English to French: {text}" for text in examples["English words/sentences"]]
#       9     targets = examples["French words/sentences"]
#      10     return tokenizer(inputs, text_target=targets, max_length=128, truncation=True)
#
# File c:\Users\UYW1KOR\AppData\Local\anaconda3\envs\projects\Lib\site-packages\datasets\dataset_dict.py:72, in DatasetDict.__getitem__(self, k)
#      70 def __getitem__(self, k) -> Dataset:
#      71     if isinstance(k, (str, NamedSplit)) or len(self) == 0:
# ---> 72         return super().__getitem__(k)
#      73     else:
#      74         available_suggested_splits = [
#      75             split for split in (Split.TRAIN, Split.TEST, Split.VALIDATION) if split in self
#      76         ]
#
# KeyError: 'English words/sentences'

# %%
from peft import LoraConfig, get_peft_model, prepare_model_for_int8_training

# LoRA configuration
lora_config = LoraConfig(
    r=8,  # Rank of the low-rank matrices
    lora_alpha=32,  # Scaling factor
    target_modules=["q", "v"],  # Target attention layers
    lora_dropout=0.1,  # Dropout for LoRA layers
    bias="none",  # No bias
    task_type="SEQ_2_SEQ_LM"  # Task type for sequence-to-sequence models
)

# Prepare the model for LoRA
model = get_peft_model(model, lora_config)

# For QLoRA (4-bit quantization)
model = prepare_model_for_int8_training(model)

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
    output_dir="marianmt-lora-finetuned",
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=10,  # Fewer epochs due to fine-tuning
    logging_dir="./logs",
    logging_steps=100,
    save_steps=500,
    evaluation_strategy="steps",
    eval_steps=500,
    save_total_limit=2,
    fp16=True,  # Use mixed precision for faster training
    push_to_hub=False,
)

# %%
from transformers import Trainer

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_data["train"],
    eval_dataset=tokenized_data["validation"],
    tokenizer=tokenizer,
)

# Start fine-tuning
trainer.train()

# %%
model.save_pretrained("marianmt-lora-finetuned")
tokenizer.save_pretrained("marianmt-lora-finetuned")

# %%
from transformers import pipeline

# Load the fine-tuned model
model = AutoModelForSeq2SeqLM.from_pretrained("marianmt-lora-finetuned")
tokenizer = AutoTokenizer.from_pretrained("marianmt-lora-finetuned")

# Create a translation pipeline
translator = pipeline("translation_en_to_fr", model=model, tokenizer=tokenizer)

# Translate a sentence
english_sentence = "Hello, how are you?"
french_translation = translator(english_sentence)
print(f"English: {english_sentence}")
print(f"French: {french_translation[0]['translation_text']}")
